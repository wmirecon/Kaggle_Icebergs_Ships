# %%
import pandas as pd

# %%
icebergs_train = pd.read_json("train.json")
icebergs_test = pd.read_json("test.json")

icebergs_train.head()
# Out:
#                                               band_1  \
# 0  [-27.878360999999998, -27.15416, -28.668615, -...
# 1  [-12.242375, -14.920304999999999, -14.920363, ...
# 2  [-24.603676, -24.603714, -24.871029, -23.15277...
# 3  [-22.454607, -23.082819, -23.998013, -23.99805...
# 4  [-26.006956, -23.164886, -23.164886, -26.89116...
#
#                                               band_2        id inc_angle  \
# 0  [-27.154118, -29.537888, -31.0306, -32.190483,...  dfd5f913   43.9239
# 1  [-31.506321, -27.984554, -26.645678, -23.76760...  e25388fd   38.1562
# 2  [-24.870956, -24.092632, -20.653963, -19.41104...  58b2aaa0   45.2859
# 3  [-27.889421, -27.519794, -27.165262, -29.10350...  4cfc3a18   43.8306
# 4  [-27.206915, -30.259186, -30.259186, -23.16495...  271f93f4   35.6256
#
#    is_iceberg
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0

# %%
icebergs_test.head()
# Out:
#                                               band_1  \
# 0  [-15.863251, -15.201077, -17.887735, -19.17248...
# 1  [-26.058969497680664, -26.058969497680664, -26...
# 2  [-14.14109992980957, -15.064241409301758, -17....
# 3  [-12.167478, -13.706167, -16.54837, -13.572674...
# 4  [-23.37459373474121, -26.02718162536621, -28.1...
#
#                                               band_2        id  inc_angle
# 0  [-21.629612, -21.142353, -23.908337, -28.34524...  5941774d  34.966400
# 1  [-25.754207611083984, -25.754207611083984, -25...  4023181e  32.615072
# 2  [-14.74563980102539, -14.590410232543945, -14....  b20200e4  37.505433
# 3  [-24.32222, -26.375538, -24.096739, -23.8769, ...  e7f018bb  34.473900
# 4  [-25.72234344482422, -27.011577606201172, -23....  4371c8c3  43.918874

# %%
print(len(icebergs_train.iloc[0,1]))
print(icebergs_train.shape)
print(icebergs_test.shape)
print(icebergs_train.is_iceberg.mean())
# Out:
# 5625
# (1604, 5)
# (8424, 4)
# 0.4694513715710723

# %%
cc_fraud_data = pd.read_csv("creditcard.csv")
cc_fraud_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
import numpy as np
item_count = np.arange(0,len(icebergs_train.band_1.loc[0]))
print(len(item_count))
print(item_count)

item_label = []
for num in item_count:
    item_label.append('band_1_item_' + str(num))

icebergs_train[item_label] = pd.DataFrame(icebergs_train.band_1.values.tolist())
icebergs_train.head()
# Out:
# 5625
# [   0    1    2 ..., 5622 5623 5624]
#                                               band_1  \
# 0  [-27.878360999999998, -27.15416, -28.668615, -...
# 1  [-12.242375, -14.920304999999999, -14.920363, ...
# 2  [-24.603676, -24.603714, -24.871029, -23.15277...
# 3  [-22.454607, -23.082819, -23.998013, -23.99805...
# 4  [-26.006956, -23.164886, -23.164886, -26.89116...
#
#                                               band_2        id inc_angle  \
# 0  [-27.154118, -29.537888, -31.0306, -32.190483,...  dfd5f913   43.9239
# 1  [-31.506321, -27.984554, -26.645678, -23.76760...  e25388fd   38.1562
# 2  [-24.870956, -24.092632, -20.653963, -19.41104...  58b2aaa0   45.2859
# 3  [-27.889421, -27.519794, -27.165262, -29.10350...  4cfc3a18   43.8306
# 4  [-27.206915, -30.259186, -30.259186, -23.16495...  271f93f4   35.6256
#
#    is_iceberg  band_2_item_0  band_2_item_1  band_2_item_2  band_2_item_3  \
# 0           0     -27.878361     -27.154160     -28.668615     -29.537971
# ...
